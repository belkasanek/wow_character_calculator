# %%
import pandas as pd

from character import Character

# %%
s = Character(game_class='warlock', race='orc')

# %%
s.hp, s.mana
# Out:
# (2074, 2978)

# %% [markdown]
# ### Let's try to make warlock with rare gear. We will look towards PvP. The spell power, stamina and spell crit is important for us.

# %%
temp = s.search(slot='head', armor_type='cloth', quality='rare', 
                orderby=['Increase Spell Dam', 'Increase Shadow Dam', 'stamina', 'Increased Critical Spell'],
                additional_spell_power=True)
temp[['id', 'name', 'Increase Spell Dam', 'Increase Shadow Dam', 'stamina', 'Increased Critical Spell']].head(10)
# Out:
#           id                    name  Increase Spell Dam  Increase Shadow Dam  \
# 12181  19886      The Hexxer's Cover                  41                    0
# 11362  18727        Crimson Felt Hat                  30                    0
# 5958   10041      Dreamweave Circlet                  21                    0
# 14054  22757            Sylvan Crown                  18                    0
# 7959   13390   The Postmaster's Band                  14                    0
# 5513    9470           Bad Mojo Mask                   0                   14
# 11211  18526  Crown of the Ogre King                   0                    0
# 10277  16698          Dreadmist Mask                   0                    0
# 8285   14140       Mooncloth Circlet                   0                    0
# 10272  16693            Devout Crown                   0                    0
#
#        stamina  Increased Critical Spell
# 12181       10                       0.0
# ...

# %%
s.wear_item(ids=18727)

# %%
temp = s.search(slot='neck', armor_type='cloth', quality='rare', 
                orderby=['Increase Spell Dam', 'Increase Shadow Dam', 'stamina', 'Increased Critical Spell'],
                additional_spell_power=True)
temp[['id', 'name', 'Increase Spell Dam', 'Increase Shadow Dam', 'stamina', 'Increased Critical Spell']].head(10)
# Out:
#           id                             name  Increase Spell Dam  \
# 12216  19923        Jeklik's Opaline Talisman                  22
# 14249  23125               Chains of the Lich                  22
# 12311  20037           Arcane Crystal Pendant                  16
# 13841  22403           Diana's Pearl Necklace                   9
# 14260  23169               Scorn's Icy Choker                   7
# 11326  18691           Dark Advisor's Pendant                   0
# 11363  18728                Anastari Heirloom                   0
# 10018  16335       Senior Sergeant's Insignia                   0
# 11130  18443       Master Sergeant's Insignia                   0
# 11610  19095  Frostwolf Legionnaire's Pendant                   0
#
#        Increase Shadow Dam  stamina  Increased Critical Spell
# 12216                    0        0                       0.0
# 14249                    0        0                       0.0
# ...

# %%
s.wear_item(ids=18691)

# %%
temp = s.search(slot='shoulders', armor_type='cloth', quality='rare', 
                orderby=['Increase Spell Dam', 'Increase Shadow Dam', 'stamina', 'Increased Critical Spell'],
                additional_spell_power=True)
temp[['id', 'name', 'Increase Spell Dam', 'Increase Shadow Dam', 'stamina', 'Increased Critical Spell']].head(10)
# Out:
#           id                   name  Increase Spell Dam  Increase Shadow Dam  \
# 11317  18681           Burial Shawl                  20                    0
# 6864   11624           Kentic Amice                  14                    0
# 13558  22073       Deathmist Mantle                  12                    0
# 13567  22082        Virtuous Mantle                  12                    0
# 13850  22412        Thuzadin Mantle                  12                    0
# 7676   13013  Elder Wizard's Mantle                  11                    0
# 13553  22068      Sorcerer's Mantle                   9                    0
# 7831   13185      Sunderseer Mantle                   8                    0
# 14055  22758       Sylvan Shoulders                   7                    0
# 7661   12998      Magician's Mantle                   5                    0
#
#        stamina  Increased Critical Spell
# 11317        0                       0.0
# ...

# %%
s.wear_item(ids=22412)

# %%
temp = s.search(slot='chest', armor_type='cloth', quality='rare', 
                orderby=['Increase Spell Dam', 'Increase Shadow Dam', 'stamina', 'Increased Critical Spell'],
                additional_spell_power=True)
temp[['id', 'name', 'Increase Spell Dam', 'Increase Shadow Dam', 'stamina', 'Increased Critical Spell']].head(10)
# Out:
#           id                       name  Increase Spell Dam  \
# 11077  18385  Robe of Everlasting Night                  27
# 12032  19682             Bloodvine Vest                  27
# 12990  21183            Earthpower Vest                  25
# 532     1716           Robe of the Magi                  22
# 5479    9434          Elemental Raiment                  21
# 7041   11924   Robes of the Royal Crown                  18
# 5942   10021            Dreamweave Vest                  18
# 7957   13388     The Postmaster's Tunic                  15
# 4375    7054              Robe of Power                  14
# 14053  22756                Sylvan Vest                  12
#
#        Increase Shadow Dam  stamina  Increased Critical Spell
# 11077                    0       11                       0.0
# 12032                    0        0                       0.0
# 12990                    0        0                       0.0
# ...

# %%
s.wear_item(ids=13388)

# %%
temp = s.search(slot='back', armor_type='cloth', quality='rare', 
                orderby=['Increase Spell Dam', 'Increase Shadow Dam', 'stamina', 'Increased Critical Spell'],
                additional_spell_power=True)
temp[['id', 'name', 'Increase Spell Dam', 'Increase Shadow Dam', 'stamina', 'Increased Critical Spell']].head(10)
# Out:
#           id                             name  Increase Spell Dam  \
# 14016  22711  Cloak of the Hakkari Worshipers                  23
# 12787  20697        Crystalline Threaded Cape                  20
# 11600  19085        Frostwolf Advisor's Cloak                  14
# 11601  19086           Stormpike Sage's Cloak                  14
# 6863   11623                Spritecaster Cape                  14
# 11636  19121             Deep Woodlands Cloak                  12
# 14265  23178       Mantle of Lady Falther'ess                   9
# 14017  22712               Might of the Tribe                   0
# 7639   12967                  Bloodmoon Cloak                   0
# 10020  16342                  Sergeant's Cape                   0
#
#        Increase Shadow Dam  stamina  Increased Critical Spell
# 14016                    0        6                       0.0
# 12787                    0        5                       0.0
# ...

# %%
s.wear_item(ids=20697)

# %%
temp = s.search(slot='wrists', armor_type='cloth', quality='rare', 
                orderby=['Increase Spell Dam', 'Increase Shadow Dam', 'stamina', 'Increased Critical Spell'],
                additional_spell_power=True)
temp[['id', 'name', 'Increase Spell Dam', 'Increase Shadow Dam', 'stamina', 'Increased Critical Spell']].head(10)
# Out:
#           id                 name  Increase Spell Dam  Increase Shadow Dam  \
# 11182  18497  Sublime Wristguards                  12                    0
# 13564  22079     Virtuous Bracers                   9                    0
# 13556  22071    Deathmist Bracers                   8                    0
# 13548  22063  Sorcerer's Bindings                   8                    0
# 8721   14629      Necropile Cuffs                   0                    0
# 10282  16703    Dreadmist Bracers                   0                    0
# 7762   13107      Magiskull Cuffs                   0                    0
# 10276  16697       Devout Bracers                   0                    0
# 7073   11962        Manacle Cuffs                   0                    0
# 14253  23129   Bracers of Mending                   0                    0
#
#        stamina  Increased Critical Spell
# 11182        6                       0.0
# 13564        8                       0.0
# ...

# %%
s.wear_item(ids=22071)

# %%
temp = s.search(slot='hands', armor_type='cloth', quality='rare', 
                orderby=['Increase Spell Dam', 'Increase Shadow Dam', 'stamina', 'Increased Critical Spell'],
                additional_spell_power=True)
temp[['id', 'name', 'Increase Spell Dam', 'Increase Shadow Dam', 'stamina', 'Increased Critical Spell']].head(10)
# Out:
#           id                  name  Increase Spell Dam  Increase Shadow Dam  \
# 12806  20716  Sandworm Skin Gloves                  27                    0
# 7870   13253        Hands of Power                  26                    0
# 12220  19929    Bloodtinged Gloves                  19                    0
# 5941   10019     Dreamweave Gloves                  18                    0
# 6538   10787        Atal'ai Gloves                   9                    0
# 11099  18407       Felcloth Gloves                   0                   33
# 14252  23128    The Shadow's Grasp                   0                   20
# 6874   11634        Silkweb Gloves                   0                    0
# 10284  16705       Dreadmist Wraps                   0                    0
# 11328  18693     Shivery Handwraps                   0                    0
#
#        stamina  Increased Critical Spell
# 12806        8                       0.0
# 7870         0                       0.0
# ...

# %%
s.wear_item(ids=18407)

# %%
temp = s.search(slot='waist', armor_type='cloth', quality='rare', 
                orderby=['Increase Spell Dam', 'Increase Shadow Dam', 'stamina', 'Increased Critical Spell'],
                additional_spell_power=True)
temp[['id', 'name', 'Increase Spell Dam', 'Increase Shadow Dam', 'stamina', 'Increased Critical Spell']].head(10)
# Out:
#           id                    name  Increase Spell Dam  Increase Shadow Dam  \
# 14021  22716  Belt of Untapped Power                  29                    0
# 11605  19090    Frostwolf Cloth Belt                  18                    0
# 11609  19094  Stormpike Cloth Girdle                  18                    0
# 13547  22062         Sorcerer's Belt                  14                    0
# 13555  22070          Deathmist Belt                  12                    0
# 13563  22078           Virtuous Belt                  12                    0
# 6884   11662           Ban'thok Sash                  12                    0
# 11373  18740           Thuzadin Sash                  11                    0
# 7407   12589        Dustfeather Sash                   9                    0
# 12462  20217      Belt of Tiny Heads                   0                    0
#
#        stamina  Increased Critical Spell
# 14021        6                         0
# ...

# %%
s.wear_item(ids=22070)

# %%
temp = s.search(slot='legs', armor_type='cloth', quality='rare', 
                orderby=['Increase Spell Dam', 'Increase Shadow Dam', 'stamina', 'Increased Critical Spell'],
                additional_spell_power=True)
temp[['id', 'name', 'Increase Spell Dam', 'Increase Shadow Dam', 'stamina', 'Increased Critical Spell']].head(10)
# Out:
#           id                        name  Increase Spell Dam  \
# 12033  19683          Bloodvine Leggings                  37
# 7816   13170          Skyshroud Leggings                  34
# 12190  19895            Bloodtinged Kilt                  28
# 7637   12965       Spiritshroud Leggings                  19
# 13557  22072          Deathmist Leggings                  16
# 13552  22067         Sorcerer's Leggings                  16
# 13570  22085              Virtuous Skirt                  16
# 12795  20705  Cenarion Reservist's Pants                  15
# 11378  18745       Sacred Cloth Leggings                  14
# 14263  23173   Abomination Skin Leggings                   9
#
#        Increase Shadow Dam  stamina  Increased Critical Spell
# 12033                    0        0                       0.0
# 7816                     0        8                       0.0
# 12190                    0       20                       0.0
# ...

# %%
s.wear_item(ids=22072)

# %%
temp = s.search(slot='feet', armor_type='cloth', quality='rare', 
                orderby=['Increase Spell Dam', 'Increase Shadow Dam', 'stamina', 'Increased Critical Spell'],
                additional_spell_power=True)
temp[['id', 'name', 'Increase Spell Dam', 'Increase Shadow Dam', 'stamina', 'Increased Critical Spell']].head(10)
# Out:
#           id                     name  Increase Spell Dam  \
# 6959   11822           Omnicast Boots                  22
# 12034  19684          Bloodvine Boots                  19
# 10905  18102        Dragonrider Boots                  18
# 7757   13101         Wolfrunner Shoes                  13
# 8723   14631          Necropile Boots                  11
# 7960   13391  The Postmaster's Treads                   7
# 5498    9454           Acidic Walkers                   5
# 11368  18735       Maleki's Footwraps                   0
# 11584  19056             Argent Boots                   0
# 7392   12556     High Priestess Boots                   0
#
#        Increase Shadow Dam  stamina  Increased Critical Spell
# 6959                     0        6                         0
# 12034                    0        0                         0
# 10905                    0        5                         0
# 7757                     0       11                         0
# ...

# %%
s.wear_item(ids=14631)

# %%
temp = s.search(slot='finger1', armor_type='cloth', quality='rare', 
                orderby=['Increase Spell Dam', 'Increase Shadow Dam', 'stamina', 'Increased Critical Spell'],
                additional_spell_power=True)
temp[['id', 'name', 'Increase Spell Dam', 'Increase Shadow Dam', 'stamina', 'Increased Critical Spell']].head(10)
# Out:
#           id                    name  Increase Spell Dam  Increase Shadow Dam  \
# 7379   12543  Songstone of Ironforge                  18                    0
# 7381   12545        Eye of Orgrimmar                  18                    0
# 7664   13001         Maiden's Circle                  18                    0
# 13782  22339   Rune Band of Wizardry                  16                    0
# 11928  19518          Advisor's Ring                  14                    0
# 11932  19522       Lorekeeper's Ring                  14                    0
# 11624  19109        Deep Rooted Ring                  12                    0
# 11929  19519          Advisor's Ring                  12                    0
# 11933  19523       Lorekeeper's Ring                  12                    0
# 12188  19893           Zanzil's Seal                  11                    0
#
#        stamina  Increased Critical Spell
# 7379         0                       0.0
# ...

# %%
s.wear_item(ids=12545)
s.wear_item(ids=13001)

# %%
temp = s.search(slot='trinket1', armor_type='cloth', quality='rare', 
                orderby=['Increase Spell Dam', 'Increase Shadow Dam', 'stamina', 'Increased Critical Spell'],
                additional_spell_power=True)
temp[['id', 'name', 'Increase Spell Dam', 'Increase Shadow Dam', 'stamina', 'Increased Critical Spell']].head(10)
# Out:
#          id                           name  Increase Spell Dam  \
# 7617  12930                 Briarwood Reed                  29
# 6969  11832             Burst of Knowledge                  12
# 529    1713                   Ankh of Life                   0
# 688    1973               Orb of Deception                   0
# 1263   2802                 Blazing Emblem                   0
# 4765   7734                  Six Demon Bag                   0
# 6739  11302               Uther's Strength                   0
# 6947  11810                  Force of Will                   0
# 6948  11811  Smoking Heart of the Mountain                   0
# 6952  11815                Hand of Justice                   0
#
#       Increase Shadow Dam  stamina  Increased Critical Spell
# 7617                    0        0                         0
# 6969                    0        0                         0
# 529                     0        0                         0
# ...

# %%
s.wear_item(ids=12930)
s.wear_item(ids=11832)

# %%
temp = s.search(slot='two_hand', armor_type='cloth', quality='rare', 
                orderby=['Increase Spell Dam', 'Increase Shadow Dam', 'stamina', 'Increased Critical Spell'],
                additional_spell_power=True)
temp[['id', 'name', 'Increase Spell Dam', 'Increase Shadow Dam', 'stamina', 'Increased Critical Spell']].head(10)
# Out:
#           id                               name  Increase Spell Dam  \
# 12744  20654                 Amethyst War Staff                  34
# 12489  20258            Zulian Ceremonial Staff                  32
# 13778  22335  Lord Valthalak's Staff of Command                  30
# 14248  23124                 Staff of Balzaphon                  29
# 13776  22333             Hammer of Divine Might                  27
# 11219  18534               Rod of the Ogre Magi                  23
# 10903  18082              Zum'rah's Vexing Cane                  21
# 6585   10844                    Spire of Hakkar                  18
# 13880  22458                   Moonshadow Stave                  18
# 11616  19101                     Whiteout Staff                  15
#
#        Increase Shadow Dam  stamina  Increased Critical Spell
# 12744                    0        6                       0.0
# 12489                    0       13                       0.0
# ...

# %%
s.wear_item(ids=18534)

# %%
s.show_empty_slots()
# Out:
# ['thrown',
#  'offhand',
#  'relic',
#  'bow',
#  'one-hand',
#  'gun',
#  'shield',
#  'ranged',
#  'left-hand']

# %%
s.summary()
# Out:
# {'agility': 47,
#  'arcane_resist': 0,
#  'arcane_sp': 0,
#  'armor': 649,
#  'crit': 0,
#  'defence': 0,
#  'dodge': 2.35,
#  'fire_resist': 0,
#  'fire_sp': 0,
#  'frost_resist': 0,
#  'frost_sp': 0,
#  'healing_power': 0,
#  'hit_chance': 0,
#  'holy_resist': 0,
#  'holy_sp': 0,
#  'hp': 3374,
#  'intellect': 251,
#  'mana': 5138,
#  'mana_reg': 47.4,
#  'max_magic_reduction': 0.0,
#  'melee_ap': 48,
#  'nature_resist': 0,
#  'nature_sp': 0,
#  'parry': 0,
#  'physical_reduction': 0.09936461762229197,
#  'range_ap': 0,
#  'shadow_resist': 0,
#  'shadow_sp': 53,
#  'sp': 224,
#  'spell_crit': 4.183333333333334,
#  'spirit': 162,
#  'stamina': 196,
#  'strength': 48}

# %%
s.save('warlock_rare_items')
