# %%
import os

import configparser
import pandas as pd

from sqlalchemy import create_engine

# %% [markdown]
# ### Database taken from https://github.com/classicdb/database
# ### To create all necessary tables command below should be executed in shell
# ### You need to create new database and grant all privileges to user
# ```bash
# mysql -u 'username' -p 'password' - D 'databasename' < ./Full_DB/ClassicDB_1_7_z2684.sql
# ```

# %%
# create config file if not exist
if 'main.ini' not in os.listdir():
    config = configparser.ConfigParser()
    print('Type username, password and database name of your mysql separated whitespace')
    username, password, database = input().split(' ')
    
    config['SQL'] = {'username': username, 'password': password, 'database': database}
    with open('main.ini', 'w') as configfile:
        config.write(configfile)
# Out:
# Type username, password and database name of your mysql separated whitespace
# mongos mongos mongos

# %%
# read config file
config = configparser.ConfigParser()
config.read('main.ini')
# Out:
# ['main.ini']

# %%
engine = create_engine('mysql+pymysql://{}:{}@localhost/{}'.format(config['SQL']['username'],
                                                                   config['SQL']['password'],
                                                                   config['SQL']['database']))

# %%
# all tables in database
pd.read_sql_query("""
SHOW tables;
""", engine)
# Out:
#                       Tables_in_mongos
# 0         areatrigger_involvedrelation
# 1                   areatrigger_tavern
# 2                 areatrigger_teleport
# 3                  battleground_events
# 4                battleground_template
# 5                   battlemaster_entry
# 6                              command
# 7                           conditions
# 8                             creature
# 9                       creature_addon
# 10                 creature_ai_scripts
# 11                 creature_ai_summons
# 12                   creature_ai_texts
# 13               creature_battleground
# 14             creature_equip_template
# 15         creature_equip_template_raw
# 16           creature_involvedrelation
# 17                    creature_linking
# 18           creature_linking_template
# 19              creature_loot_template
# 20                 creature_model_info
# 21                   creature_movement
# 22          creature_movement_template
# 23          creature_onkill_reputation
# 24              creature_questrelation
# 25                   creature_template
# 26             creature_template_addon
# 27   creature_template_classlevelstats
# 28            creature_template_spells
# 29                        custom_texts
# ..                                 ...
# 92                     pool_gameobject
# 93            pool_gameobject_template
# 94                           pool_pool
# 95                       pool_template
# 96                      quest_template
# 97             reference_loot_template
# 98              reputation_reward_rate
# 99       reputation_spillover_template
# 100                      reserved_name
# 101                       script_texts
# 102                    script_waypoint
# 103               scripted_areatrigger
# 104                  scripted_event_id
# 105           skill_fishing_base_level
# 106             skinning_loot_template
# 107                       spell_affect
# 108                         spell_area
# 109                   spell_bonus_data
# 110                        spell_chain
# 111                       spell_elixir
# 112                       spell_facing
# 113                  spell_learn_spell
# 114                    spell_pet_auras
# 115                   spell_proc_event
# 116            spell_proc_item_enchant
# 117                spell_script_target
# 118              spell_target_position
# 119                       spell_threat
# 120                         transports
# 121                     world_template
#
# [122 rows x 1 columns]
